# %% [markdown]
# <a href="https://colab.research.google.com/github/DevKumar57-67/QROS-AI/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This main.py file contains complete Python Programming Language from basic to advanced
#The file is the part of our Qros AI Project

print("HELLO QROS")
print("This is python programming language")
print("This is Python")
# Out:
# HELLO QROS
# This is python programming language
# This is Python

# %%
# basic operations
x = 50
y = 66
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x/y)
# Out:
# 116
# -16
# 3300
# 0.7575757575757576
# 0.7575757575757576

# %%
# INPUT / OUTPUT

x = int(input("Enter the value of x"))
y = int(input("Enter the value of y"))

print("The sum is",x+y)
# Out:
# Enter the value of x45
# Enter the value of y78
# The sum is 123
